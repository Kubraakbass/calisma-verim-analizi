# %%
import pandas as pd

# %%
df=pd.DataFrame({
    "gun":[1,2,3,4,5],
    "calısma suresi":[10,7,8,6,9]
})
df
# Out:
#    gun  calısma suresi
# 0    1              10
# 1    2               7
# 2    3               8
# 3    4               6
# 4    5               9

# %%
df.to_excel("ornek_veri.xlsx", index=False)

# %%
df2 =pd.read_excel("ornek_veri.xlsx")
df2
# Out:
#    gun  calısma suresi
# 0    1              10
# 1    2               7
# 2    3               8
# 3    4               6
# 4    5               9

# %%
df2["calısma suresi"].mean()
# Out:
# 8.0

# %%
df2["calısma suresi"].sum()
# Out:
# 40

# %%
#devam edeceğim.

# %%
df2["calısma suresi"].min()
# Out:
# 6

# %%
df2["calısma suresi"].idxmin()
# Out:
# 3

# %%
df2.loc[df2["calısma suresi"].idxmin()]
# Out:
# gun               4
# calısma suresi    6
# Name: 3, dtype: int64

# %%
df2["calısma suresi"].plot()
# Out:
# <Axes: >

# %%
df2.plot(x="gun",y="calısma suresi")
# Out:
# <Axes: xlabel='gun'>

# %%
df2.plot(x="gun",y="calısma suresi",kind="bar")
# Out:
# <Axes: xlabel='gun'>

# %%
# Günlere göre çalışma süreleri incelendiğinde,
# en yüksek çalışma süresinin 1. ve 5. günlerde olduğu görülmektedir.
# En düşük çalışma süresi ise 4. günde gerçekleşmiştir.
# Günler arasında belirgin bir dalgalanma bulunmaktadır.

# %%
df2["verim"] = [3, 2, 3, 1, 2]
df2
# Out:
#    gun  calısma suresi  verim
# 0    1              10      3
# 1    2               7      2
# 2    3               8      3
# 3    4               6      1
# 4    5               9      2

# %%
df2.groupby("verim")["calısma suresi"].mean()
# Out:
# verim
# 1    6.0
# 2    8.0
# 3    9.0
# Name: calısma suresi, dtype: float64

# %%
df2.plot(kind="scatter",x="verim",y="calısma suresi")
# Out:
# <Axes: xlabel='verim', ylabel='calısma suresi'>

# %%
df2.groupby("verim")["calısma suresi"].mean().plot(kind="bar")
# Out:
# <Axes: xlabel='verim'>

# %%
calisma-verim-analizi/
│
├── data/
│   └── calisma_20gun.xlsx
│
├── notebook/
│   └── analiz.ipynb
│
├── README.md
└── requirements.txt
# Out:
#   Cell In[11], line 2
#     │
#     ^
# SyntaxError: invalid character '│' (U+2502)
